# %%
# %config Completer.use_jedi = False

# %%
import georasters as gr
import pandas as pd

# %%
pwd
# Out:
# '/home/joaquinfunes/ProyectoIntegrador_Weather/Notebooks'

# %%
# Abro archivos tiff que fueron generados en base a archivos .grib2 (GFS)
elevation50kISBL = gr.from_file('../gfsRaster/geotiff/2020_01/02_06/GFS_None_HGT_50000_2020-01-02Z15:00.tiff')
elevation70kISBL = gr.from_file('../gfsRaster/geotiff/2020_01/02_06/GFS_None_HGT_70000_2020-01-02Z15:00.tiff')
elevation100kISBL = gr.from_file('../gfsRaster/geotiff/2020_01/02_06/GFS_None_HGT_100000_2020-01-02Z15:00.tiff')

# %%
elevation50kISBL.plot()
elevation70kISBL.plot()
elevation100kISBL.plot()
# Out:
# <AxesSubplot:>

# %%
df_elevation50kISBL = elevation50kISBL.to_pandas()
df_elevation70kISBL = elevation70kISBL.to_pandas()
df_elevation100kISBL = elevation100kISBL.to_pandas()

# %%
df_elevation50kISBL # value: metros - x:longitud  -  y: latitud
# Out:
#           row   col        value          x          y
# 0           0     0  5891.099121 -75.000000 -25.000000
# 1           0     1  5891.099121 -74.991015 -25.000000
# 2           0     2  5891.099121 -74.982030 -25.000000
# 3           0     3  5891.099121 -74.973044 -25.000000
# 4           0     4  5891.099121 -74.964059 -25.000000
# ...       ...   ...          ...        ...        ...
# 3157743  1668  1887  5822.499023 -58.044926 -39.991013
# 3157744  1668  1888  5822.499023 -58.035941 -39.991013
# 3157745  1668  1889  5822.499023 -58.026956 -39.991013
# 3157746  1668  1890  5822.499023 -58.017970 -39.991013
# 3157747  1668  1891  5822.499023 -58.008985 -39.991013
#
# [3157748 rows x 5 columns]

# %%
df_elevation70kISBL
# Out:
#           row   col        value          x          y
# 0           0     0  3165.310791 -75.000000 -25.000000
# 1           0     1  3165.310791 -74.991015 -25.000000
# 2           0     2  3165.310791 -74.982030 -25.000000
# 3           0     3  3165.310791 -74.973044 -25.000000
# 4           0     4  3165.310791 -74.964059 -25.000000
# ...       ...   ...          ...        ...        ...
# 3157743  1668  1887  3157.486816 -58.044926 -39.991013
# 3157744  1668  1888  3157.486816 -58.035941 -39.991013
# 3157745  1668  1889  3157.486816 -58.026956 -39.991013
# 3157746  1668  1890  3157.486816 -58.017970 -39.991013
# 3157747  1668  1891  3157.486816 -58.008985 -39.991013
#
# [3157748 rows x 5 columns]

# %%
df_elevation100kISBL
# Out:
#           row   col       value          x          y
# 0           0     0  152.456558 -75.000000 -25.000000
# 1           0     1  152.456558 -74.991015 -25.000000
# 2           0     2  152.456558 -74.982030 -25.000000
# 3           0     3  152.456558 -74.973044 -25.000000
# 4           0     4  152.456558 -74.964059 -25.000000
# ...       ...   ...         ...        ...        ...
# 3157743  1668  1887  192.168549 -58.044926 -39.991013
# 3157744  1668  1888  192.168549 -58.035941 -39.991013
# 3157745  1668  1889  192.168549 -58.026956 -39.991013
# 3157746  1668  1890  192.168549 -58.017970 -39.991013
# 3157747  1668  1891  192.168549 -58.008985 -39.991013
#
# [3157748 rows x 5 columns]

# %%
############################################################################################################

# %%
# Abro archivo tiff que fue generado en base a archivo .nc (la salida de wrf)
file_tiff = gr.from_file('wrf-meteo/geotiff/CBA_A_06_RAINNC_2020-01-01T12:00.tiff')

# %%
file_tiff.plot()
# Out:
# <AxesSubplot:>

# %%
file_pd = file_tiff.to_pandas()

# %%
file_pd  #value: mm de lluvia
# Out:
#        row  col     value       x       y
# 0        0    0  0.000000 -67.000 -29.000
# 1        0    1  0.000000 -66.964 -29.000
# 2        0    2  0.000000 -66.928 -29.000
# 3        0    3  0.000000 -66.892 -29.000
# 4        0    4  0.000000 -66.856 -29.000
# ...    ...  ...       ...     ...     ...
# 30620  174  170  0.000722 -60.880 -35.264
# 30621  174  171  0.001445 -60.844 -35.264
# 30622  174  172  0.001722 -60.808 -35.264
# 30623  174  173  0.001722 -60.772 -35.264
# 30624  174  174  0.001609 -60.736 -35.264
#
# [30625 rows x 5 columns]
