# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
history = pickle.load( open( "/opt/datos/entrenamientos/larraondo/trainHistoryDict_vgg16_0-2-6", "rb" ) )

print(f"val_loss: {history['val_loss'][-1]}")
print(f"loss: {history['loss'][-1]}")
#print(history)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('VGG16 network training 1000-800-400 hPa')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# val_loss: 0.2656249403953552
# loss: 0.1908324956893921

# %%
history = pickle.load( open( "/opt/datos/entrenamientos/larraondo/trainHistoryDict_vgg16_0-3-5", "rb" ) )

print(f"val_loss: {history['val_loss'][-1]}")
print(f"loss: {history['loss'][-1]}")
#print(history)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('VGG16 network training 1000-700-500 hPa')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# val_loss: 0.26757603883743286
# loss: 0.1905730962753296

# %%
history = pickle.load( open( "/opt/datos/entrenamientos/larraondo/trainHistoryDict_vgg16_val_0-2-6", "rb" ) )

print("~ Dataset dividido correctamente ~")
print(f"val_loss: {history['val_loss'][-1]}")
print(f"loss: {history['loss'][-1]}")
#print(history)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('VGG16 network training 1000-800-400 hPa')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# ~ Dataset dividido correctamente ~
# val_loss: 0.27524247765541077
# loss: 0.19100067019462585

# %%
history = pickle.load( open( "/opt/datos/entrenamientos/larraondo/trainHistoryDict_unet_val_0-2-6", "rb" ) )

print("~ Dataset dividido correctamente ~")
print(f"val_loss: {history['val_loss'][-1]}")
print(f"loss: {history['loss'][-1]}")
#print(history)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Unet network training 1000-800-400 hPa')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# ~ Dataset dividido correctamente ~
# val_loss: 0.23882867395877838
# loss: 0.1906137466430664

# %%
history1 = pickle.load( open( "/opt/datos/entrenamientos/larraondo/trainHistoryDict_vgg16_0-2-6", "rb" ) )
history2 = pickle.load( open( "/opt/datos/entrenamientos/larraondo/trainHistoryDict_vgg16_val_0-2-6", "rb" ) )

print("~ VGG16 mal dividido vs VGG16 dividido correctamente ~")
print(f"val_loss mal dividido: {history1['val_loss'][-1]}")
print(f"val_loss bien dividido: {history2['val_loss'][-1]}")
#print(history)
plt.plot(history1['val_loss'])
plt.plot(history2['val_loss'])
plt.title('Validation MAE during training 1000-800-400 hPa')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.legend(['VGG16 mal', 'VGG16 bien'], loc='upper right')
plt.show()
# Out:
# ~ VGG16 mal dividido vs VGG16 dividido correctamente ~
# val_loss mal dividido: 0.2656249403953552
# val_loss bien dividido: 0.27524247765541077

# %%
history1 = pickle.load( open( "/opt/datos/entrenamientos/larraondo/trainHistoryDict_vgg16_val_0-2-6", "rb" ) )
history2 = pickle.load( open( "/opt/datos/entrenamientos/larraondo/trainHistoryDict_unet_val_0-2-6", "rb" ) )

print("~ VGG16 vs Unet ~")
print(f"val_loss VGG16: {history1['val_loss'][-1]}")
print(f"val_loss Unet: {history2['val_loss'][-1]}")
#print(history)
plt.plot(history1['val_loss'])
plt.plot(history2['val_loss'])
plt.title('Validation MAE during training 1000-800-400 hPa')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.legend(['VGG16', 'Unet'], loc='upper right')
plt.show()
# Out:
# ~ VGG16 vs Unet ~
# val_loss VGG16: 0.27524247765541077
# val_loss Unet: 0.23882867395877838

# %% [markdown]
# ## opt = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)  -  loss=mae

# %%
history = pickle.load( open( "/opt/datos/entrenamientos/7", "rb" ) )

print(f"val_loss: {history['val_loss'][-1]}")
print(f"loss: {history['loss'][-1]}")
#print(history)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Unet network training 1000-800-400 hPa')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
#plt.ylim(0,0.4)
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# val_loss: 0.09853973984718323
# loss: 0.21350260078907013

# %% [markdown]
# ## opt = SGD(lr=0.1, decay=1e-2, momentum=0.9, nesterov=True)  -  loss=mae

# %%
history = pickle.load( open( "/opt/datos/entrenamientos/1", "rb" ) )

print(f"val_loss: {history['val_loss'][-1]}")
print(f"loss: {history['loss'][-1]}")
#print(history)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Unet network training 1000-800-400 hPa')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.ylim(0,0.4)
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# val_loss: 0.09739378839731216
# loss: 0.20838573575019836

# %% [markdown]
# ## opt = SGD(lr=0.1, decay=1e-2, momentum=0.9, nesterov=False)  -  loss=mae

# %%
history = pickle.load( open( "/opt/datos/entrenamientos/6", "rb" ) )

print(f"val_loss: {history['val_loss'][-1]}")
print(f"loss: {history['loss'][-1]}")
#print(history)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Unet network training 1000-800-400 hPa')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
#plt.ylim(0,0.4)
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# val_loss: 0.098642997443676
# loss: 0.20835460722446442

# %% [markdown]
# ## opt = SGD(lr=0.5, decay=1e-2, momentum=0.9, nesterov=True)  -  loss=mae

# %%
history = pickle.load( open( "/opt/datos/entrenamientos/2", "rb" ) )

#print("~ Dataset dividido correctamente ~")
print(f"val_loss: {history['val_loss'][-1]}")
print(f"loss: {history['loss'][-1]}")
#print(history)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Unet network training 1000-800-400 hPa')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
#plt.ylim(0,0.8)
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# val_loss: 1.0240188837051392
# loss: 0.21375201642513275

# %% [markdown]
# ## opt = SGD(lr=0.25, decay=1e-2, momentum=0.9, nesterov=True) - loss=mae

# %%
history = pickle.load( open( "/opt/datos/entrenamientos/5", "rb" ) )

#print("~ Dataset dividido correctamente ~")
print(f"val_loss: {history['val_loss'][-1]}")
print(f"loss: {history['loss'][-1]}")
#print(history)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Unet network training 1000-800-400 hPa')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.ylim(0,0.5)
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# val_loss: 0.09799736738204956
# loss: 0.21014687418937683

# %% [markdown]
# ## Adam(lr=0.001)  -  loss=mae

# %%
history = pickle.load( open( "/opt/datos/entrenamientos/3", "rb" ) )

#print("~ Dataset dividido correctamente ~")
print(f"val_loss: {history['val_loss'][-1]}")
print(f"loss: {history['loss'][-1]}")
#print(history)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Unet network training 1000-800-400 hPa')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.ylim(0,2)
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# val_loss: 0.09836440533399582
# loss: 0.2092813402414322

# %% [markdown]
# ## Adam(lr=0.01)  -  loss=mae

# %%
history = pickle.load( open( "/opt/datos/entrenamientos/4", "rb" ) )

#print("~ Dataset dividido correctamente ~")
print(f"val_loss: {history['val_loss'][-1]}")
print(f"loss: {history['loss'][-1]}")
#print(history)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Unet network training 1000-800-400 hPa')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
#plt.ylim(0,0.5)
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# val_loss: 0.09807602316141129
# loss: 0.2082323133945465
